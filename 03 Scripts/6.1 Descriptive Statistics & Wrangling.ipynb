# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
"""
File: gun-violence-data_01-2013_03-2018.csv
Author:Erica Henry
Date: 03/30/24

#Description: Importing of raw data gun-violence-data_01-2013_03-2018.csv 
"""

gun_vio =pd.read_csv(r"C:\Users\HP\03-2024 Gun Violence\02 Data\Original Data\gun-violence-data_01-2013_03-2018.csv",index_col=False)

# %%
#Creating string for project folder path

# %%
path=r"C:\Users\HP\03-2024 Gun Violence"

# %%
#Importing gun-violence-data_01-2013_03-2018.csv via path

# %%
gun_vio =pd.read_csv(os.path.join(path,"02 Data","Original Data","gun-violence-data_01-2013_03-2018.csv"),index_col= False)

# %%
gun_vio.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
gun_vio.shape
# Out:
# (239677, 29)

# %%
gun_vio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %%
gun_vio.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %%
#Descriptive Statistics

# %%
gun_vio.describe()
# Out:
#         incident_id       n_killed      n_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#             latitude      longitude  n_guns_involved  state_house_district  \
# count  231754.000000  231754.000000    140226.000000         200905.000000
# mean       37.546598     -89.338348         1.372442             55.447132
# std         5.130763      14.359546         4.678202             42.048117
# ...

# %%
"""
File: gun-violence-data_01-2013_03-2018.csv
Author:Erica Henry
Date: 03/30/24

#Description: Removing columns not needed 
"""

#Removing 'sources', 'source_url', 'incident_url_fields_missing', 'incident_url columns
gun_vio = gun_vio.drop(columns = ['sources', 'source_url', 'incident_url_fields_missing', 'incident_url', 'participant_name'])

# %%
#Check output
gun_vio.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'congressional_district', 'gun_stolen', 'gun_type',
#        'incident_characteristics', 'latitude', 'location_description',
#        'longitude', 'n_guns_involved', 'notes', 'participant_age',
#        'participant_age_group', 'participant_gender',
#        'participant_relationship', 'participant_status', 'participant_type',
#        'state_house_district', 'state_senate_district'],
#       dtype='object')

# %%
#Summary Info of Dataframe
gun_vio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_id               239677 non-null  int64
#  1   date                      239677 non-null  object
#  2   state                     239677 non-null  object
#  3   city_or_county            239677 non-null  object
#  4   address                   223180 non-null  object
#  5   n_killed                  239677 non-null  int64
#  6   n_injured                 239677 non-null  int64
#  7   congressional_district    227733 non-null  float64
#  8   gun_stolen                140179 non-null  object
#  9   gun_type                  140226 non-null  object
#  10  incident_characteristics  239351 non-null  object
#  11  latitude                  231754 non-null  float64
#  12  location_description      42089 non-null   object
# ...

# %%
"""
File: gun-violence-data_01-2013_03-2018.csv
Author:Erica Henry
Date: 03/30/24

#Description: Renaming columns to more suitable names 
"""

gun_vio.rename(columns = {'n_guns_involved' : 'guns_count_involved'}, inplace = True)

# %%
gun_vio.rename(columns = {'n_killed' : 'count_killed'}, inplace = True)

# %%
gun_vio.rename(columns = {'n_injured' : 'count_of_injured'}, inplace = True)

# %%
gun_vio.rename(columns = {'incident_characteristics' : 'incident_details'}, inplace = True)

# %%
gun_vio.rename(columns = {'participant_type' : 'participant_involvement'}, inplace = True)

# %%
gun_vio.rename(columns = {'address' : 'address_of_incident'}, inplace = True)

# %%
gun_vio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_id               239677 non-null  int64
#  1   date                      239677 non-null  object
#  2   state                     239677 non-null  object
#  3   city_or_county            239677 non-null  object
#  4   address_of_incident       223180 non-null  object
#  5   count_killed              239677 non-null  int64
#  6   count_of_injured          239677 non-null  int64
#  7   congressional_district    227733 non-null  float64
#  8   gun_stolen                140179 non-null  object
#  9   gun_type                  140226 non-null  object
#  10  incident_details          239351 non-null  object
#  11  latitude                  231754 non-null  float64
#  12  location_description      42089 non-null   object
# ...

# %%
#Exporting gun-violence-data_01-2013_03-2018 dataframe as gun_vio_wrangled.csv
gun_vio.to_csv(os.path.join(path,"02 Data","Prepared Data","gun_vio_wrangled.csv"))
